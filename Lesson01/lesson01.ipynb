# %%
# Install required libraries
# !pip install --upgrade pip
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn
# !pip install xlrd

# %%
# Import required libraries
import pandas as pd
import numpy as np
import matplotlib as mpl
import seaborn as sn

pd.set_option('display.max_columns', None)

# %% [markdown]
# <H3> Dicionário das variáveis </H3>
#
# `LIMT_BAL:`
#     - Valor do crédito concedido (dólar NT): inclui tanto o crédito ao consumidor individual quanto o crédito familiar (complementar) - Limite total de crédito concedido aos cliente.
# `SEX:`
#     - Genero (1 = Homem; 2 = Mulher).
# `EDUCATION:`
#     - Education (1 = graduate school; 2 = university; 3 = high school; 4 = others).
# `MARRIAGE:`
#     - Marital status (1 = married; 2 = single; 3 = others).
# `AGE:`
#     - Age (year).
# `PAY_1 - PAY_6:`
#     - Histórico de pagamentos anteriores. Acompanhamos os registros de pagamentos mensais anteriores (de abril a setembro de 2005) da seguinte forma: X6 = situação de pagamento em setembro de 2005; X7 = situação de reembolso em agosto de 2005; . . .;X11 = situação de reembolso em abril de 2005. A escala de mensuração da situação de reembolso é: -1 = pagar em dia; 1 = atraso de pagamento de um mês; 2 = atraso no pagamento há dois meses; . . .; 8 = atraso no pagamento há oito meses; 9 = atraso no pagamento por nove meses ou mais.
# `BILL_AMT1 - BILL_AMT6:`
#     - Valor do extrato da conta (dólar NT). X12 = valor do extrato da conta em setembro de 2005; X13 = valor do extrato da conta em agosto de 2005; . . .; X17 = valor do extrato da conta em abril de 2005.
# `PAY_AMT1 - PAY_AMT6:`
#     - Valor do pagamento anterior (dólar NT). X18 = valor pago em setembro de 2005; X19 = valor pago em agosto de 2005; . . .;X23 = valor pago em abril de 2005.
#
#
# `TARGET - default payment next month:`
#     - Esta pesquisa empregou uma variável binária, pagamento inadimplente (Sim = 1, Não = 0), como variável resposta. Este estudo revisou a literatura e utilizou as seguintes 23 variáveis ​​como variáveis ​​explicativas.

# %%
df = pd.read_excel('C:/Users/vinic/Desktop/Data Science/Data-science-projects-with-python/Data/default_of_credit_card_clients__courseware_version_1_21_19.xls')
df.head()
# Out:
#               ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE PAY_1  PAY_2  \
# 0  798fc410-45c1      20000    2          2         1   24     2      2
# 1  8a8c8f3b-8eb4     120000    2          2         2   26    -1      2
# 2  85698822-43f5      90000    2          2         2   34     0      0
# 3  0737c11b-be42      50000    2          2         1   37     0      0
# 4  3b7f77cc-dbc0      50000    1          2         1   57    -1      0
#
#    PAY_3  PAY_4  PAY_5  PAY_6  BILL_AMT1  BILL_AMT2  BILL_AMT3  BILL_AMT4  \
# 0     -1     -1     -2     -2       3913       3102        689          0
# 1      0      0      0      2       2682       1725       2682       3272
# 2      0      0      0      0      29239      14027      13559      14331
# 3      0      0      0      0      46990      48233      49291      28314
# 4     -1      0      0      0       8617       5670      35835      20940
#
#    BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  PAY_AMT4  PAY_AMT5  \
# ...

# %%
# Size of the Dataframe
df.shape
# Out:
# (30000, 25)
